# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import copy
import pickle
import numpy as np
from matplotlib import cm
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

import sys
sys.path.append('../')
import sim
import plot
import parse

# Workflows
PATH_TO_YAML = '../workflows/acu - tina.yaml'

# %%
yaml = parse.load_yaml(PATH_TO_YAML)
simulation = parse.create_simulation_from_yaml(yaml)
simulation.draw_workflow_diagram(figsize=(50,50), path_to_file='../output/ACU Workflow.pdf')
